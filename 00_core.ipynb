# %% [raw]
# ---
# description: API details.
# output-file: core.html
# title: module name here
#
# ---

# %%
#| default_exp core

# %%
#| include: false
from nbdev.showdoc import *

# %% [markdown]
# ## [nbdev](https://nbdev.fast.ai) basics
# - [Tutorial](https://nbdev.fast.ai/tutorial.html)
